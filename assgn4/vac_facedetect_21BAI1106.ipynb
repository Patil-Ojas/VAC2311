# %% [markdown]
# # Face detection using Haar cascade classifier
#
# Name - Ojas Patil
#
# Reg No - 21BAI1106

# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425344 sha256=79becbf829a682a38c37601febaa922b3df4c47297bf9ae319be43698087bcdb
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# %%
spark = SparkSession.builder.appName("FaceDetection").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7763632b27d0:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>FaceDetection</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import cv2
import sys

# %%
imagePath = "/content/people_img.jpg"
cascPath = "haarcascade_frontalface_default.xml"

faceCascade = cv2.CascadeClassifier(cascPath)

image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=3,
    minSize=(1,1),
    flags = cv2.CASCADE_SCALE_IMAGE
)

for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

print("Detected {0} faces!".format(len(faces)))
# Out:
# Detected 4 faces!

# %%
from google.colab.patches import cv2_imshow

print
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=698x423>
# -1

# %%
imagePath = "/content/people_img.jpg"
cascPath = "/content/haarcascade_frontalface_alt.xml"

faceCascade = cv2.CascadeClassifier(cascPath)

image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=3,
    minSize=(1,1),
    flags = cv2.CASCADE_SCALE_IMAGE
)

for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

print("Detected {0} faces!".format(len(faces)))
# Out:
# Detected 2 faces!

# %%
from google.colab.patches import cv2_imshow

print
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=698x423>
# -1

# %%
imagePath = "/content/people_img.jpg"
cascPath = "/content/haarcascade_frontalface_alt2.xml"

faceCascade = cv2.CascadeClassifier(cascPath)

image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=3,
    minSize=(1,1),
    flags = cv2.CASCADE_SCALE_IMAGE
)

for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

print("Detected {0} faces!".format(len(faces)))
# Out:
# Detected 4 faces!

# %%
from google.colab.patches import cv2_imshow

print
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=698x423>
# -1
